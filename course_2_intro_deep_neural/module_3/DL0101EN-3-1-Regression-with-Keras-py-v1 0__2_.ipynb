# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Download-and-Clean-the-Data-Set">Download and Clean the Data Set</a><br>
# 2. <a href="#Import-Keras-Packages">Import Keras Packages</a><br>
# 3. <a href="#Build-a-Neural-Network">Build a Neural Network</a><br>
# 4. <a href="#Train-and-Test-the-Network">Train and Test the Network</a><br>
#
# </font>
# </div>

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below.:
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# Out:
# Collecting numpy==2.0.2
#   Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 37.3 MB/s eta 0:00:00:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.0.2
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.2) (2024.2)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 132.0 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2025.2
# Collecting tensorflow_cpu==2.18.0
#   Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow_cpu==2.18.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow_cpu==2.18.0)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow_cpu==2.18.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow_cpu==2.18.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow_cpu==2.18.0)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow_cpu==2.18.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow_cpu==2.18.0)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow_cpu==2.18.0)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow_cpu==2.18.0)
#   Downloading grpcio-1.73.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow_cpu==2.18.0)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow_cpu==2.18.0)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Collecting h5py>=3.11.0 (from tensorflow_cpu==2.18.0)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow_cpu==2.18.0)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2024.12.14)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow_cpu-2.18.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (230.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 MB 41.5 MB/s eta 0:00:0000:0100:01
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.73.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 10.1 MB/s eta 0:00:00ta 0:00:01
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 33.1 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.3 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 47.6 MB/s eta 0:00:00:00:01
# Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 34.0 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 48.5 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-1.17.2-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 46.7 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, mdurl, markdown, h5py, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, markdown-it-py, rich, keras, tensorflow_cpu
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.73.1 h5py-3.14.0 keras-3.10.0 libclang-18.1.1 markdown-3.8.2 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.1.0 opt-einsum-3.4.0 optree-0.16.0 protobuf-5.29.5 rich-14.0.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow_cpu-2.18.0 termcolor-3.1.0 werkzeug-3.1.3 wrapt-1.17.2

# %% [markdown]
# #### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# ## Download and Clean the Data Set

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 56ms/step - loss: 1656.8390 - val_loss: 1161.3870
# Epoch 2/100
# 23/23 - 0s - 8ms/step - loss: 1536.1796 - val_loss: 1054.9696
# Epoch 3/100
# 23/23 - 0s - 8ms/step - loss: 1337.4164 - val_loss: 882.2917
# Epoch 4/100
# 23/23 - 0s - 8ms/step - loss: 1024.7081 - val_loss: 641.1093
# Epoch 5/100
# 23/23 - 0s - 7ms/step - loss: 649.5702 - val_loss: 395.3771
# Epoch 6/100
# 23/23 - 0s - 7ms/step - loss: 360.3887 - val_loss: 241.9050
# Epoch 7/100
# 23/23 - 0s - 7ms/step - loss: 250.0212 - val_loss: 188.6852
# Epoch 8/100
# 23/23 - 0s - 7ms/step - loss: 225.5929 - val_loss: 171.6924
# Epoch 9/100
# 23/23 - 0s - 8ms/step - loss: 211.5109 - val_loss: 170.3830
# Epoch 10/100
# 23/23 - 0s - 8ms/step - loss: 201.5907 - val_loss: 162.5883
# Epoch 11/100
# 23/23 - 0s - 8ms/step - loss: 193.9702 - val_loss: 161.6395
# Epoch 12/100
# 23/23 - 0s - 7ms/step - loss: 187.6091 - val_loss: 156.1488
# Epoch 13/100
# 23/23 - 0s - 8ms/step - loss: 182.2570 - val_loss: 154.9247
# Epoch 14/100
# 23/23 - 0s - 8ms/step - loss: 177.6348 - val_loss: 154.6226
# Epoch 15/100
# 23/23 - 0s - 8ms/step - loss: 173.1799 - val_loss: 152.2043
# Epoch 16/100
# 23/23 - 0s - 8ms/step - loss: 170.2823 - val_loss: 151.4986
# Epoch 17/100
# 23/23 - 0s - 8ms/step - loss: 166.1483 - val_loss: 148.2424
# Epoch 18/100
# 23/23 - 0s - 7ms/step - loss: 162.9186 - val_loss: 148.8400
# Epoch 19/100
# 23/23 - 0s - 6ms/step - loss: 159.9678 - val_loss: 149.3148
# Epoch 20/100
# 23/23 - 0s - 7ms/step - loss: 41.9904 - val_loss: 123.3714
# Epoch 83/100
# 23/23 - 0s - 7ms/step - loss: 41.3354 - val_loss: 120.5416
# Epoch 84/100
# 23/23 - 0s - 7ms/step - loss: 40.9361 - val_loss: 113.3367
# Epoch 85/100
# 23/23 - 0s - 7ms/step - loss: 40.2088 - val_loss: 120.4190
# Epoch 86/100
# 23/23 - 0s - 6ms/step - loss: 40.2188 - val_loss: 116.0835
# Epoch 87/100
# 23/23 - 0s - 7ms/step - loss: 39.2324 - val_loss: 120.2760
# Epoch 88/100
# 23/23 - 0s - 7ms/step - loss: 39.0832 - val_loss: 121.7365
# Epoch 89/100
# 23/23 - 0s - 7ms/step - loss: 38.6293 - val_loss: 120.1319
# Epoch 90/100
# 23/23 - 0s - 7ms/step - loss: 38.2495 - val_loss: 115.9793
# Epoch 91/100
# 23/23 - 0s - 7ms/step - loss: 37.4211 - val_loss: 120.3522
# Epoch 92/100
# 23/23 - 0s - 7ms/step - loss: 37.6720 - val_loss: 118.7001
# Epoch 93/100
# 23/23 - 0s - 7ms/step - loss: 37.6678 - val_loss: 106.4847
# Epoch 94/100
# 23/23 - 0s - 7ms/step - loss: 37.7680 - val_loss: 110.6615
# Epoch 95/100
# 23/23 - 0s - 7ms/step - loss: 36.6341 - val_loss: 120.7136
# Epoch 96/100
# 23/23 - 0s - 7ms/step - loss: 36.2553 - val_loss: 115.5382
# Epoch 97/100
# 23/23 - 0s - 7ms/step - loss: 35.3680 - val_loss: 118.7443
# Epoch 98/100
# 23/23 - 0s - 7ms/step - loss: 35.5497 - val_loss: 113.4409
# Epoch 99/100
# 23/23 - 0s - 7ms/step - loss: 34.9866 - val_loss: 121.3369
# Epoch 100/100
# 23/23 - 0s - 7ms/step - loss: 35.0920 - val_loss: 122.1681

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
# Write your code here
# define regression model
def regression_model_5layer():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# build the model
model_1 = regression_model_5layer()

# %%
# fit the model
model_1.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 2s - 87ms/step - loss: 1523.4546 - val_loss: 845.2274
# Epoch 2/100
# 23/23 - 0s - 10ms/step - loss: 678.4706 - val_loss: 391.2807
# Epoch 3/100
# 23/23 - 0s - 10ms/step - loss: 302.4956 - val_loss: 244.1608
# Epoch 4/100
# 23/23 - 0s - 10ms/step - loss: 237.8925 - val_loss: 218.1909
# Epoch 5/100
# 23/23 - 0s - 9ms/step - loss: 217.6524 - val_loss: 197.8672
# Epoch 6/100
# 23/23 - 0s - 9ms/step - loss: 201.9832 - val_loss: 187.0570
# Epoch 7/100
# 23/23 - 0s - 9ms/step - loss: 183.5152 - val_loss: 177.5499
# Epoch 8/100
# 23/23 - 0s - 9ms/step - loss: 169.7378 - val_loss: 184.8380
# Epoch 9/100
# 23/23 - 0s - 9ms/step - loss: 154.2740 - val_loss: 161.1686
# Epoch 10/100
# 23/23 - 0s - 9ms/step - loss: 133.6496 - val_loss: 173.6041
# Epoch 11/100
# 23/23 - 0s - 8ms/step - loss: 116.9592 - val_loss: 152.2178
# Epoch 12/100
# 23/23 - 0s - 8ms/step - loss: 100.8906 - val_loss: 184.5232
# Epoch 13/100
# 23/23 - 0s - 8ms/step - loss: 89.2565 - val_loss: 172.8209
# Epoch 14/100
# 23/23 - 0s - 8ms/step - loss: 74.5023 - val_loss: 161.8035
# Epoch 15/100
# 23/23 - 0s - 9ms/step - loss: 63.4738 - val_loss: 150.7783
# Epoch 16/100
# 23/23 - 0s - 8ms/step - loss: 60.2032 - val_loss: 164.9597
# Epoch 17/100
# 23/23 - 0s - 8ms/step - loss: 51.7572 - val_loss: 183.3514
# Epoch 18/100
# 23/23 - 0s - 9ms/step - loss: 49.7847 - val_loss: 165.7860
# Epoch 19/100
# 23/23 - 0s - 8ms/step - loss: 49.5486 - val_loss: 171.2883
# Epoch 20/100
# 23/23 - 0s - 8ms/step - loss: 45.8115 - val_loss: 178.5228
# Epoch 21/100
# 23/23 - 0s - 8ms/step - loss: 43.0407 - val_loss: 174.3817
# Epoch 22/100
# 23/23 - 0s - 8ms/step - loss: 42.5503 - val_loss: 180.5231
# Epoch 23/100
# 23/23 - 0s - 8ms/step - loss: 41.0119 - val_loss: 163.4878
# Epoch 24/100
# 23/23 - 0s - 8ms/step - loss: 40.1147 - val_loss: 158.8643
# Epoch 25/100
# 23/23 - 0s - 9ms/step - loss: 38.1277 - val_loss: 161.6830
# Epoch 26/100
# 23/23 - 0s - 8ms/step - loss: 38.1031 - val_loss: 180.3884
# Epoch 27/100
# 23/23 - 0s - 8ms/step - loss: 37.1338 - val_loss: 170.5926
# Epoch 28/100
# 23/23 - 0s - 9ms/step - loss: 35.9916 - val_loss: 177.5251
# Epoch 29/100
# 23/23 - 0s - 9ms/step - loss: 33.4958 - val_loss: 159.8819
# Epoch 30/100
# 23/23 - 0s - 9ms/step - loss: 33.5198 - val_loss: 180.8274
# Epoch 31/100
# 23/23 - 0s - 9ms/step - loss: 30.6036 - val_loss: 172.4826
# Epoch 32/100
# 23/23 - 0s - 9ms/step - loss: 31.8851 - val_loss: 168.3527
# Epoch 33/100
# 23/23 - 0s - 8ms/step - loss: 29.4482 - val_loss: 174.5704
# Epoch 34/100
# 23/23 - 0s - 8ms/step - loss: 29.5659 - val_loss: 173.3645
# Epoch 35/100
# 23/23 - 0s - 8ms/step - loss: 27.8349 - val_loss: 172.7013
# Epoch 36/100
# 23/23 - 0s - 8ms/step - loss: 29.2575 - val_loss: 164.9539
# Epoch 37/100
# 23/23 - 0s - 8ms/step - loss: 26.2463 - val_loss: 177.5941
# Epoch 38/100
# 23/23 - 0s - 8ms/step - loss: 26.9222 - val_loss: 170.7298
# Epoch 39/100
# 23/23 - 0s - 8ms/step - loss: 27.3206 - val_loss: 179.4723
# Epoch 40/100
# 23/23 - 0s - 8ms/step - loss: 25.2787 - val_loss: 164.4363
# Epoch 41/100
# 23/23 - 0s - 8ms/step - loss: 24.1976 - val_loss: 181.8753
# Epoch 42/100
# 23/23 - 0s - 8ms/step - loss: 24.4403 - val_loss: 167.6575
# Epoch 43/100
# 23/23 - 0s - 8ms/step - loss: 22.0921 - val_loss: 139.4009
# Epoch 44/100
# 23/23 - 0s - 9ms/step - loss: 21.6238 - val_loss: 178.1718
# Epoch 45/100
# 23/23 - 0s - 13ms/step - loss: 23.7027 - val_loss: 151.6564
# Epoch 46/100
# 23/23 - 0s - 8ms/step - loss: 22.5190 - val_loss: 154.2458
# Epoch 47/100
# 23/23 - 0s - 8ms/step - loss: 20.2863 - val_loss: 148.9625
# Epoch 48/100
# 23/23 - 0s - 8ms/step - loss: 19.5133 - val_loss: 157.0309
# Epoch 49/100
# 23/23 - 0s - 8ms/step - loss: 19.0302 - val_loss: 166.6172
# Epoch 50/100
# 23/23 - 0s - 8ms/step - loss: 18.7995 - val_loss: 171.0995
# Epoch 51/100
# 23/23 - 0s - 8ms/step - loss: 18.5784 - val_loss: 170.9188
# Epoch 52/100
# 23/23 - 0s - 8ms/step - loss: 18.3238 - val_loss: 162.3702
# Epoch 53/100
# 23/23 - 0s - 8ms/step - loss: 18.5328 - val_loss: 150.3916
# Epoch 54/100
# 23/23 - 0s - 8ms/step - loss: 17.9001 - val_loss: 140.7311
# Epoch 55/100
# 23/23 - 0s - 8ms/step - loss: 16.5854 - val_loss: 167.3985
# Epoch 56/100
# 23/23 - 0s - 9ms/step - loss: 17.2950 - val_loss: 171.0634
# Epoch 57/100
# 23/23 - 0s - 8ms/step - loss: 16.2525 - val_loss: 170.4756
# Epoch 58/100
# 23/23 - 0s - 8ms/step - loss: 15.8142 - val_loss: 169.6943
# Epoch 59/100
# 23/23 - 0s - 8ms/step - loss: 15.5042 - val_loss: 162.1020
# Epoch 60/100
# 23/23 - 0s - 8ms/step - loss: 15.2340 - val_loss: 145.9991
# Epoch 61/100
# 23/23 - 0s - 8ms/step - loss: 16.2138 - val_loss: 154.2194
# Epoch 62/100
# 23/23 - 0s - 8ms/step - loss: 16.3951 - val_loss: 167.2612
# Epoch 63/100
# 23/23 - 0s - 9ms/step - loss: 15.5743 - val_loss: 180.5593
# Epoch 64/100
# 23/23 - 0s - 8ms/step - loss: 15.5565 - val_loss: 159.8255
# Epoch 65/100
# 23/23 - 0s - 8ms/step - loss: 15.0348 - val_loss: 168.4427
# Epoch 66/100
# 23/23 - 0s - 8ms/step - loss: 15.4794 - val_loss: 151.0097
# Epoch 67/100
# 23/23 - 0s - 8ms/step - loss: 14.5923 - val_loss: 146.0254
# Epoch 68/100
# 23/23 - 0s - 8ms/step - loss: 13.5420 - val_loss: 174.1767
# Epoch 100/100
# 23/23 - 0s - 8ms/step - loss: 11.1078 - val_loss: 169.9286

# %% [markdown]
# **Loss is lower now with the increase of 5 hidden layers,but `val_loss` is higher.**

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# def regression_model():
#     input_colm = predictors_norm.shape[1] # Number of input features
#     # create model
#     model = Sequential()
#     model.add(Input(shape=(input_colm,)))  # Set the number of input features
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(50, activation='relu'))
#     model.add(Dense(1))  # Output layer
#
#     # compile model
#     model.compile(optimizer='adam', loss='mean_squared_error')
#     return model
#
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
# Write your code here

model_1 = regression_model_5layer()
model_1.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 3s - 87ms/step - loss: 1502.0703 - val_loss: 923.6635
# Epoch 2/100
# 29/29 - 0s - 8ms/step - loss: 662.1323 - val_loss: 302.9042
# Epoch 3/100
# 29/29 - 0s - 8ms/step - loss: 241.0127 - val_loss: 210.8852
# Epoch 4/100
# 29/29 - 0s - 8ms/step - loss: 204.5682 - val_loss: 188.3772
# Epoch 5/100
# 29/29 - 0s - 7ms/step - loss: 186.2834 - val_loss: 179.0317
# Epoch 6/100
# 29/29 - 0s - 8ms/step - loss: 172.0237 - val_loss: 165.0335
# Epoch 7/100
# 29/29 - 0s - 7ms/step - loss: 159.2563 - val_loss: 156.1109
# Epoch 8/100
# 29/29 - 0s - 7ms/step - loss: 150.3143 - val_loss: 154.6576
# Epoch 9/100
# 29/29 - 0s - 8ms/step - loss: 143.1593 - val_loss: 142.5467
# Epoch 10/100
# 29/29 - 0s - 7ms/step - loss: 135.3168 - val_loss: 136.4621
# Epoch 11/100
# 29/29 - 0s - 8ms/step - loss: 127.2966 - val_loss: 121.9082
# Epoch 12/100
# 29/29 - 0s - 7ms/step - loss: 116.9331 - val_loss: 114.0737
# Epoch 13/100
# 29/29 - 0s - 7ms/step - loss: 101.8434 - val_loss: 100.9982
# Epoch 14/100
# 29/29 - 0s - 8ms/step - loss: 89.5887 - val_loss: 90.9242
# Epoch 15/100
# 29/29 - 0s - 7ms/step - loss: 77.5379 - val_loss: 80.2427
# Epoch 16/100
# 29/29 - 0s - 8ms/step - loss: 66.3786 - val_loss: 60.7186
# Epoch 17/100
# 29/29 - 0s - 7ms/step - loss: 59.8960 - val_loss: 50.2258
# Epoch 18/100
# 29/29 - 0s - 8ms/step - loss: 53.6310 - val_loss: 50.9734
# Epoch 19/100
# 29/29 - 0s - 7ms/step - loss: 48.4688 - val_loss: 51.1987
# Epoch 20/100
# 29/29 - 0s - 8ms/step - loss: 49.7831 - val_loss: 43.8629
# Epoch 21/100
# 29/29 - 0s - 9ms/step - loss: 41.5440 - val_loss: 35.4053
# Epoch 22/100
# 29/29 - 0s - 7ms/step - loss: 41.1189 - val_loss: 32.3926
# Epoch 23/100
# 29/29 - 0s - 7ms/step - loss: 38.5614 - val_loss: 32.8836
# Epoch 24/100
# 29/29 - 0s - 7ms/step - loss: 36.1624 - val_loss: 31.6424
# Epoch 25/100
# 29/29 - 0s - 7ms/step - loss: 33.8812 - val_loss: 33.0720
# Epoch 26/100
# 29/29 - 0s - 7ms/step - loss: 31.8985 - val_loss: 28.9718
# Epoch 27/100
# 29/29 - 0s - 7ms/step - loss: 31.2884 - val_loss: 28.3463
# Epoch 28/100
# 29/29 - 0s - 8ms/step - loss: 31.4103 - val_loss: 28.8356
# Epoch 29/100
# 29/29 - 0s - 7ms/step - loss: 28.8528 - val_loss: 26.0776
# Epoch 30/100
# 29/29 - 0s - 8ms/step - loss: 27.7303 - val_loss: 26.0576
# Epoch 31/100
# 29/29 - 0s - 8ms/step - loss: 28.5316 - val_loss: 31.4656
# Epoch 32/100
# 29/29 - 0s - 7ms/step - loss: 28.0439 - val_loss: 28.8355
# Epoch 33/100
# 29/29 - 0s - 8ms/step - loss: 25.6524 - val_loss: 37.3048
# Epoch 34/100
# 29/29 - 0s - 8ms/step - loss: 24.7233 - val_loss: 25.6602
# Epoch 35/100
# 29/29 - 0s - 7ms/step - loss: 25.2532 - val_loss: 30.7462
# Epoch 36/100
# 29/29 - 0s - 7ms/step - loss: 25.1330 - val_loss: 25.5921
# Epoch 37/100
# 29/29 - 0s - 7ms/step - loss: 22.1565 - val_loss: 26.0101
# Epoch 38/100
# 29/29 - 0s - 7ms/step - loss: 22.5588 - val_loss: 27.4186
# Epoch 39/100
# 29/29 - 0s - 7ms/step - loss: 21.8257 - val_loss: 23.9532
# Epoch 40/100
# 29/29 - 0s - 8ms/step - loss: 21.8139 - val_loss: 27.7215
# Epoch 41/100
# 29/29 - 0s - 8ms/step - loss: 21.3500 - val_loss: 25.9866
# Epoch 42/100
# 29/29 - 0s - 8ms/step - loss: 21.3099 - val_loss: 24.5336
# Epoch 43/100
# 29/29 - 0s - 7ms/step - loss: 21.3554 - val_loss: 23.5030
# Epoch 44/100
# 29/29 - 0s - 8ms/step - loss: 20.1595 - val_loss: 24.0343
# Epoch 45/100
# 29/29 - 0s - 7ms/step - loss: 19.3544 - val_loss: 33.1197
# Epoch 46/100
# 29/29 - 0s - 7ms/step - loss: 21.9325 - val_loss: 22.0634
# Epoch 47/100
# 29/29 - 0s - 7ms/step - loss: 19.5262 - val_loss: 29.7386
# Epoch 48/100
# 29/29 - 0s - 8ms/step - loss: 20.6378 - val_loss: 32.3290
# Epoch 49/100
# 29/29 - 0s - 7ms/step - loss: 19.2316 - val_loss: 22.9567
# Epoch 50/100
# 29/29 - 0s - 7ms/step - loss: 18.3289 - val_loss: 28.4919
# Epoch 51/100
# 29/29 - 0s - 7ms/step - loss: 19.4311 - val_loss: 21.9999
# Epoch 52/100
# 29/29 - 0s - 7ms/step - loss: 17.6205 - val_loss: 21.9295
# Epoch 53/100
# 29/29 - 0s - 8ms/step - loss: 17.7882 - val_loss: 22.8632
# Epoch 54/100
# 29/29 - 0s - 8ms/step - loss: 17.6656 - val_loss: 21.9289
# Epoch 55/100
# 29/29 - 0s - 8ms/step - loss: 16.6725 - val_loss: 26.3217
# Epoch 56/100
# 29/29 - 0s - 8ms/step - loss: 16.9266 - val_loss: 20.1152
# Epoch 57/100
# 29/29 - 0s - 10ms/step - loss: 17.1551 - val_loss: 28.6397
# Epoch 58/100
# 29/29 - 0s - 7ms/step - loss: 16.5299 - val_loss: 25.0912
# Epoch 59/100
# 29/29 - 0s - 7ms/step - loss: 17.2082 - val_loss: 20.7809
# Epoch 60/100
# 29/29 - 0s - 7ms/step - loss: 17.4941 - val_loss: 25.5071
# Epoch 61/100
# 29/29 - 0s - 7ms/step - loss: 16.7290 - val_loss: 21.7371
# Epoch 62/100
# 29/29 - 0s - 7ms/step - loss: 16.0378 - val_loss: 22.9348
# Epoch 63/100
# 29/29 - 0s - 8ms/step - loss: 17.4656 - val_loss: 28.2894
# Epoch 64/100
# 29/29 - 0s - 7ms/step - loss: 17.5641 - val_loss: 26.7480
# Epoch 65/100
# 29/29 - 0s - 7ms/step - loss: 16.1174 - val_loss: 23.2252
# Epoch 66/100
# 29/29 - 0s - 7ms/step - loss: 16.2893 - val_loss: 19.9791
# Epoch 67/100
# 29/29 - 0s - 7ms/step - loss: 14.6327 - val_loss: 19.4868
# Epoch 68/100
# 29/29 - 0s - 7ms/step - loss: 16.5266 - val_loss: 22.1902
# Epoch 69/100
# 29/29 - 0s - 6ms/step - loss: 15.5622 - val_loss: 18.8280
# Epoch 70/100
# 29/29 - 0s - 7ms/step - loss: 14.1938 - val_loss: 18.3153
# Epoch 71/100
# 29/29 - 0s - 7ms/step - loss: 15.2081 - val_loss: 18.1762
# Epoch 72/100
# 29/29 - 0s - 7ms/step - loss: 14.1506 - val_loss: 20.2623
# Epoch 73/100
# 29/29 - 0s - 7ms/step - loss: 13.6771 - val_loss: 17.1349
# Epoch 74/100
# 29/29 - 0s - 6ms/step - loss: 15.3172 - val_loss: 18.6642
# Epoch 75/100
# 29/29 - 0s - 7ms/step - loss: 14.4403 - val_loss: 16.9748
# Epoch 76/100
# 29/29 - 0s - 7ms/step - loss: 14.1197 - val_loss: 17.5287
# Epoch 77/100
# 29/29 - 0s - 7ms/step - loss: 15.9836 - val_loss: 21.7776
# Epoch 78/100
# 29/29 - 0s - 7ms/step - loss: 13.8946 - val_loss: 15.9082
# Epoch 79/100
# 29/29 - 0s - 7ms/step - loss: 14.4669 - val_loss: 30.3772
# Epoch 80/100
# 29/29 - 0s - 7ms/step - loss: 13.6118 - val_loss: 18.2942
# Epoch 81/100
# 29/29 - 0s - 7ms/step - loss: 13.9381 - val_loss: 16.2103
# Epoch 82/100
# 29/29 - 0s - 7ms/step - loss: 13.2981 - val_loss: 17.9328
# Epoch 83/100
# 29/29 - 0s - 7ms/step - loss: 13.4132 - val_loss: 19.0999
# Epoch 84/100
# 29/29 - 0s - 7ms/step - loss: 13.4031 - val_loss: 17.2627
# Epoch 85/100
# 29/29 - 0s - 7ms/step - loss: 13.4053 - val_loss: 20.4177
# Epoch 86/100
# 29/29 - 0s - 7ms/step - loss: 13.0483 - val_loss: 16.8560
# Epoch 87/100
# 29/29 - 0s - 8ms/step - loss: 12.7982 - val_loss: 19.9892
# Epoch 88/100
# 29/29 - 0s - 8ms/step - loss: 14.3583 - val_loss: 18.2350
# Epoch 89/100
# 29/29 - 0s - 8ms/step - loss: 12.8321 - val_loss: 16.7231
# Epoch 90/100
# 29/29 - 0s - 7ms/step - loss: 12.5846 - val_loss: 15.2063
# Epoch 91/100
# 29/29 - 0s - 7ms/step - loss: 15.2937 - val_loss: 24.6204
# Epoch 92/100
# 29/29 - 0s - 7ms/step - loss: 14.9907 - val_loss: 16.0602
# Epoch 93/100
# 29/29 - 0s - 8ms/step - loss: 13.3448 - val_loss: 15.7415
# Epoch 94/100
# 29/29 - 0s - 7ms/step - loss: 14.1441 - val_loss: 18.9323
# Epoch 95/100
# 29/29 - 0s - 7ms/step - loss: 12.8350 - val_loss: 16.2658
# Epoch 96/100
# 29/29 - 0s - 7ms/step - loss: 12.4692 - val_loss: 16.6504
# Epoch 97/100
# 29/29 - 0s - 7ms/step - loss: 12.1594 - val_loss: 14.3676
# Epoch 98/100
# 29/29 - 0s - 7ms/step - loss: 12.7223 - val_loss: 15.5593
# Epoch 99/100
# 29/29 - 0s - 7ms/step - loss: 12.5069 - val_loss: 14.9635
# Epoch 100/100
# 29/29 - 0s - 7ms/step - loss: 13.7771 - val_loss: 16.4205

# %% [markdown]
# **Now we see that both `loss` and `val_loss` are lower, but this is because more data is available to learn more so loss gets lower. However, there is less data for validation so `val_loss` is lower but less data is used for validation.**

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = regression_model()
# model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
#
# -->

# %% [markdown]
# Based on the results, we notice that:
#
# - Adding more hidden layers to the model increases its capacity to learn and represent complex relationships within the data. This allows the model to better identify, as a result, the model becomes more effective at fitting the training data and potentially improving its predictions.
# - By reducing the proportion of data set aside for validation and using a larger portion for training, the model has access to more examples to learn from. This additional training data helps the model improve its understanding of the underlying trends, which can lead to better overall performance.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
